# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Assessment 1

# %% [markdown]
# Question.1
# Import pandas and read in the banklist.csv file into a dataframe called
# banks.

# %%
#Question 1
data = pd.read_csv("/content/banklist.csv")
data
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 548                                 Superior Bank, FSB            Hinsdale
# 549                                Malta National Bank               Malta
# 550                    First Alliance Bank & Trust Co.          Manchester
# 551                  National State Bank of Metropolis          Metropolis
# 552                                   Bank of Honolulu            Honolulu
#
# ...

# %% [markdown]
# Question 2.Show the head of the dataframe

# %%
#Question2
data.head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17    26-Jul-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17    26-Jul-17
# 2  58302                         Whitney Bank    28-Apr-17    26-Jul-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %% [markdown]
# Question.3 What are the column names?

# %%
#Question3
data.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %% [markdown]
# Question.4 How many States (ST) are represented in this data set?

# %%
#Question4
data["ST"].nunique()
# Out:
# 44

# %% [markdown]
# Question.5 Get a list or array of all the states in the data set.

# %%
#Question5
data["ST"].unique()
# Out:
# array(['IL', 'WI', 'LA', 'UT', 'NJ', 'AR', 'GA', 'PA', 'TN', 'WA', 'CO',
#        'PR', 'FL', 'MN', 'CA', 'MD', 'OK', 'OH', 'SC', 'VA', 'ID', 'TX',
#        'CT', 'AZ', 'NV', 'NC', 'KY', 'MO', 'KS', 'AL', 'MI', 'IN', 'IA',
#        'NE', 'MS', 'NM', 'OR', 'NY', 'MA', 'SD', 'WY', 'WV', 'NH', 'HI'],
#       dtype=object)

# %% [markdown]
# Question.6 What are the top 5 states with the most failed banks?

# %%
#Questio6
data.groupby(("ST"))["CERT"].sum().sort_values().head()
# Out:
# ST
# WV     6782
# HI    21029
# WY    22754
# MA    26619
# MS    30087
# Name: CERT, dtype: int64

# %% [markdown]
# Question.7  What are the top 5 acquiring institutions?

# %%
#Question7
data.groupby(("Acquiring Institution"))["Bank Name"].count().sort_values(ascending= False).head(5)
# Out:
# Acquiring Institution
# No Acquirer                            31
# State Bank and Trust Company           12
# First-Citizens Bank & Trust Company    11
# Ameris Bank                            10
# U.S. Bank N.A.                          9
# Name: Bank Name, dtype: int64

# %% [markdown]
# Question.8 How many banks has the State Bank of Texas acquired? How many of them were actually in Texas?

# %%
#Question8
a= data[data["Acquiring Institution"] == "State Bank of Texas"]
print("Those banks has acquired state bank of texas:",len(a))
g = data[(data["Acquiring Institution"] == "State Bank of Texas") & (data["ST"] == "TX")]
d = len(g)
print("Those banks were actully in Texas:",d)
# Out:
# Those banks has acquired state bank of texas: 3
# Those banks were actully in Texas: 1

# %% [markdown]
# Question.9 What is the most common city in California for a bank to fail in?

# %%
#Question9
data[(data["CERT"].sort_values(ascending=True)) & (data["ST"] == "CA")]
# Out:
# <ipython-input-10-13e2fae68cbb>:2: FutureWarning: Operation between non boolean Series with different indexes will no longer return a boolean result in a future version. Cast both Series to object type to maintain the prior behavior.
#   data[(data["CERT"].sort_values(ascending=True)) & (data["ST"] == "CA")]
#                                 Bank Name             City  ST   CERT  \
# 131  Citizens Bank of Northern California      Nevada City  CA  33983
# 182              San Luis Trust Bank, FSB  San Luis Obispo  CA  34783
# 183                      Charter Oak Bank             Napa  CA  57855
# 218        First Vietnamese American Bank      Westminster  CA  57885
# 220               Western Commercial Bank   Woodland Hills  CA  58087
# 243                    Sonoma Valley Bank           Sonoma  CA  27259
# 244                       Los Padres Bank          Solvang  CA  32165
# 245                  Butte Community Bank            Chico  CA  33219
# ...

# %% [markdown]
# # Assessment 2

# %%
#Assessment 2:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Q 1: Develop a Line chart using the functionality of pandas to show how
# automobile sales fluctuate from year to year.

# %%
ds = pd.read_csv("/content/historical_automobile_sales.csv")
ds
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# ...

# %%
ds.columns
# Out:
# Index(['Date', 'Year', 'Month', 'Recession', 'Consumer_Confidence',
#        'Seasonality_Weight', 'Price', 'Advertising_Expenditure', 'Competition',
#        'GDP', 'Growth_Rate', 'unemployment_rate', 'Automobile_Sales',
#        'Vehicle_Type', 'City'],
#       dtype='object')

# %%
sns.lineplot(x="Year",y="Automobile_Sales",data=ds,color= "green")
# Out:
# <Axes: xlabel='Year', ylabel='Automobile_Sales'>

# %%
ds ["Recession"] = ds["Recession"].map({1:"Yes",0:"No"})

# %%
ds['Date'] = pd.to_datetime(ds['Date'])

# %% [markdown]
# Q 2: Plot different lines for categories of vehicle type and analyze the trend
# to answer the question Is there a noticeable difference in sales trends
# between different vehicle types during recession periods?

# %%
ds['Date'] = pd.to_datetime(ds['Date'])
plt.figure(figsize=(14, 7))
sns.lineplot(data=ds,x='Date',y='Automobile_Sales',hue='Vehicle_Type',style='Recession')
plt.title("Automobile Sales Trends by Vehicle Type During Recession Periods")
plt.xlabel("Date")
plt.ylabel("Automobile Sales")
plt.legend(title='Vehicle Type / Recession')
plt.tight_layout()
plt.show()

# %% [markdown]
# Q 3: Use the functionality of Seaborn Library to create a visualization to compare
# the sales trend per vehicle type for a recession period with a non- recession
# period.

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='Vehicle_Type',y='Automobile_Sales',hue='Recession',data=ds)
plt.title("Total Vehicle Sales: Recession VS No Recession")
# Out:
# Text(0.5, 1.0, 'Total Vehicle Sales: Recession VS No Recession')

# %%
a = ds["Automobile_Sales"].sum()

# %% [markdown]
# Q 4: Now you want to compare the sales of different vehicle types during a recession and a non-recession period

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Vehicle_Type',y='Automobile_Sales',hue='Recession',data=ds)
plt.title(f"Total Sales:-{a:.2f}")
# Out:
# Text(0.5, 1.0, 'Total Sales:-1242235.14')
